# %%
# !/Applications/bioinfo/bedtools2/bin/complementBed \
-i tracks/Panopea-generosa-vv0.74.a3.gene.gff3 \
-g analyses/Pg_genome.tab | head
# Out:
# PGA_scaffold1__77_contigs__length_89643857	17292	19807
# PGA_scaffold1__77_contigs__length_89643857	54226	56261
# PGA_scaffold1__77_contigs__length_89643857	81099	109518
# PGA_scaffold1__77_contigs__length_89643857	109911	110225
# PGA_scaffold1__77_contigs__length_89643857	141242	141271
# PGA_scaffold1__77_contigs__length_89643857	141553	143262
# PGA_scaffold1__77_contigs__length_89643857	176313	183685
# PGA_scaffold1__77_contigs__length_89643857	186073	187327
# PGA_scaffold1__77_contigs__length_89643857	187864	189848
# PGA_scaffold1__77_contigs__length_89643857	190460	191068
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5288797-5289052 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5336078-5339567 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ...

# %%
# !/Applications/bioinfo/bedtools2/bin/complementBed \
-i tracks/Panopea-generosa-vv0.74.a3.gene.gff3 \
-g analyses/Pg_genome.tab \
> tracks/Panopea-generosa-vv0.74.a3.intragenic.bed
# Out:
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5288797-5289052 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5336078-5339567 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5347089-5420826 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5433543-5433882 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5449305-5460402 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ***** WARNING: PGA_scaffold4__129_contigs__length_65288255:5468159-5492425 exceeds the length of chromosome (PGA_scaffold4__129_contigs__length_65288255)
# ...

# %%
# !head tracks/Panopea-generosa-vv0.74.a3.intragenic.bed
# Out:
# PGA_scaffold1__77_contigs__length_89643857	17292	19807
# PGA_scaffold1__77_contigs__length_89643857	54226	56261
# PGA_scaffold1__77_contigs__length_89643857	81099	109518
# PGA_scaffold1__77_contigs__length_89643857	109911	110225
# PGA_scaffold1__77_contigs__length_89643857	141242	141271
# PGA_scaffold1__77_contigs__length_89643857	141553	143262
# PGA_scaffold1__77_contigs__length_89643857	176313	183685
# PGA_scaffold1__77_contigs__length_89643857	186073	187327
# PGA_scaffold1__77_contigs__length_89643857	187864	189848
# PGA_scaffold1__77_contigs__length_89643857	190460	191068
