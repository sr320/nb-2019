# %%
# !ls /Volumes/Serine/wd/19-11-04/
# Out:
# CHG_OB_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-152_S3_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-153_S4_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-154_S5_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-159_S6_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-160_S7_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-161_S8_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-162_S9_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-167_S10_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-168_S11_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-169_S12_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OB_EPI-170_S13_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OT_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# CHG_OT_EPI-152_S3_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# ...

# %%
# !ls /Volumes/Serine/wd/19-11-04/*151*
# Out:
# /Volumes/Serine/wd/19-11-04/CHG_OB_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# /Volumes/Serine/wd/19-11-04/CHG_OT_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# /Volumes/Serine/wd/19-11-04/CHH_OB_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# /Volumes/Serine/wd/19-11-04/CHH_OT_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# /Volumes/Serine/wd/19-11-04/CpG_OB_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# /Volumes/Serine/wd/19-11-04/CpG_OT_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt
# /Volumes/Serine/wd/19-11-04/EPI-151_S2_L002_R1_001_val_1_bismark_bt2_PE_report.html
# /Volumes/Serine/wd/19-11-04/EPI-151_S2_L002_R1_001_val_1_bismark_bt2_PE_report.txt
# /Volumes/Serine/wd/19-11-04/EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.bam
# /Volumes/Serine/wd/19-11-04/EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.M-bias.txt
# ...

# %%
# !head /Volumes/Serine/wd/19-11-04/*151*txt
# Out:
# ==> /Volumes/Serine/wd/19-11-04/CHG_OB_EPI-151_S2_L002_R1_001_val_1_bismark_bt2_pe.deduplicated.txt <==
# Bismark methylation extractor version v0.21.0
# D00743:144:CAAWNANXX:2:2207:10948:2248_1:N:0:ATCACG	-	PGA_scaffold16__33_contigs__length_31980953	11416938	x
# D00743:144:CAAWNANXX:2:2207:9181:2250_1:N:0:ATCACG	-	PGA_scaffold7__69_contigs__length_43120122	36066829	x
# D00743:144:CAAWNANXX:2:2207:10948:2248_1:N:0:ATCACG	-	PGA_scaffold16__33_contigs__length_31980953	11416929	x
# D00743:144:CAAWNANXX:2:2207:10948:2248_1:N:0:ATCACG	-	PGA_scaffold16__33_contigs__length_31980953	11416919	x
# D00743:144:CAAWNANXX:2:2207:9181:2250_1:N:0:ATCACG	-	PGA_scaffold7__69_contigs__length_43120122	36066819	x
# D00743:144:CAAWNANXX:2:2207:10948:2248_1:N:0:ATCACG	-	PGA_scaffold16__33_contigs__length_31980953	11416857	x
# D00743:144:CAAWNANXX:2:2207:2268:2425_1:N:0:ATCACG	-	PGA_scaffold2__36_contigs__length_69596280	64550755	x
# ...
