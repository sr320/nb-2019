# %%
# !head data/uniprot-yourlist_M201909166746803381A1F0E0DB47453E0216320DAFE49B2.tab
# Out:
# Entry	Entry name	Protein names	Gene ontology (biological process)
# Q8PVR7	DNLI1_METMA	DNA ligase 1 (EC 6.5.1.1) (Polydeoxyribonucleotide synthase [ATP] 1)	DNA biosynthetic process [GO:0071897]; DNA ligation involved in DNA repair [GO:0051103]; DNA recombination [GO:0006310]; DNA replication [GO:0006260]; cell cycle [GO:0007049]; cell division [GO:0051301]
# ...

# %%
# !grep "immune" data/uniprot-yourlist_M201909166746803381A1F0E0DB47453E0216320DAFE49B2.tab | awk -F $'\t' 'BEGIN {OFS = FS} {print $3}'
# Out:
# Toll-like receptor 5
# Myeloid differentiation primary response protein MyD88
# Protein toll
# Immunoglobulin heavy constant gamma 3 (HDC) (Heavy chain disease protein) (Ig gamma-3 chain C region)
# Interleukin-15 (IL-15)
# Tyrosine-protein kinase HCK (EC 2.7.10.2) (Hematopoietic cell kinase) (Hemopoietic cell kinase) (p56-HCK)
# Protein Nef (3'ORF) (Negative factor) (F-protein) [Cleaved into: C-terminal core protein]
# Double-stranded RNA-specific adenosine deaminase (DRADA) (EC 3.5.4.37) (136 kDa double-stranded RNA-binding protein) (p136) (Interferon-inducible protein 4) (IFI-4) (K88DSRBP)
# Poly [ADP-ribose] polymerase (PARP) (EC 2.4.2.30) (NAD(+) ADP-ribosyltransferase) (ADPRT) (Poly[ADP-ribose] synthase) (Protein ADP-ribosyltransferase Parp) (EC 2.4.2.-)
# E3 ubiquitin-protein ligase Itchy homolog (Itch) (EC 2.3.2.26) (Atrophin-1-interacting protein 4) (AIP4) (HECT-type E3 ubiquitin transferase Itchy homolog) (NFE2-associated polypeptide 1) (NAPP1)
# ...

# %%
# !grep "temperature" data/uniprot-yourlist_M201909166746803381A1F0E0DB47453E0216320DAFE49B2.tab | awk -F $'\t' 'BEGIN {OFS = FS} {print $3}'
# Out:
# Chaperone protein HtpG (Heat shock protein HtpG) (High temperature protein G)
# Chaperone protein HtpG (Heat shock protein HtpG) (High temperature protein G)
# D(1A) dopamine receptor (Dopamine D1 receptor)
# Actin-related protein 6
# Tachykinin-4 (Preprotachykinin-C) (PPT-C) [Cleaved into: Hemokinin (HK1) (Hemokinin-1) (Hemokinin-I) (HK-I)]
# Chaperone protein HtpG (Heat shock protein HtpG) (High temperature protein G)
# Chaperone protein HtpG (Heat shock protein HtpG) (High temperature protein G)
# Transient receptor potential cation channel subfamily V member 2 (TrpV2) (Osm-9-like TRP channel 2) (OTRPC2) (Vanilloid receptor-like protein 1) (VRL-1)
# ...

# %%
# !grep "defense" data/uniprot-yourlist_M201909166746803381A1F0E0DB47453E0216320DAFE49B2.tab | awk -F $'\t' 'BEGIN {OFS = FS} {print $3}'
# Out:
# Probable V-type proton ATPase 116 kDa subunit a (V-ATPase 116 kDa isoform a) (Uncoordinated protein 32) (Vacuolar proton translocating ATPase 116 kDa subunit a)
# Toll-like receptor 5
# Myeloid differentiation primary response protein MyD88
# Protein toll
# Neurogenic locus Notch protein [Cleaved into: Processed neurogenic locus Notch protein]
# "Aconitate hydratase, mitochondrial (Aconitase) (EC 4.2.1.3) (Citrate hydro-lyase)"
# Serrate RNA effector molecule homolog (Arsenite-resistance protein 2 homolog)
# Immunoglobulin heavy constant gamma 3 (HDC) (Heavy chain disease protein) (Ig gamma-3 chain C region)
# Beta-glucosidase 23 (AtBGLU23) (EC 3.2.1.21) (Protein PHOSPHATE STARVATION-RESPONSE 3.1)
# Dicer-like protein 1 [Includes: Endoribonuclease DCL1 (EC 3.1.26.-); ATP-dependent helicase DCL1 (EC 3.6.4.-)]
# Interleukin-15 (IL-15)
# Obg-like ATPase 1 (EC 3.6.5.-) (Ribosome-binding ATPase YchF) (OsYchF1)
# Basic endochitinase (EC 3.2.1.14) (Fragment)
# ...
